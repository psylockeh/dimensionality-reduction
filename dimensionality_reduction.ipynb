# %% [markdown]
# <a href="https://colab.research.google.com/github/psylockeh/dimensionality-reduction/blob/main/dimensionality_reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
imagem = cv2.imread('/content/lenna.png')
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

plt.imshow(imagem_rgb)
plt.title('Imagem Original')
plt.axis('off')
plt.show()

# %%
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

plt.imshow(imagem_cinza, cmap='gray')
plt.title('Imagem em Cinza')
plt.axis('off')
plt.show()

# %%
_, imagem_binaria = cv2.threshold(imagem_cinza, 127, 255, cv2.THRESH_BINARY)

plt.imshow(imagem_binaria, cmap='gray')
plt.title('Imagem Binária')
plt.axis('off')
plt.show()
